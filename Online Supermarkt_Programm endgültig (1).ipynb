# %%
# Anna Dreier (262327), Norina Eisenbacher, Isabell Hinger (262330)
# Online Supermarkt

import pandas as pd
import ipywidgets as widgets
import time 

class color:
   BLAU = '\033[94m'
   GRÜN = '\033[92m'
   GELB = '\033[93m'
   ROT = '\033[91m'
   FETT = '\033[1m'
   END = '\033[0m'


df = pd.read_csv('Liste_Gemüse.CSV', delimiter=';')
gv = pd.read_csv('Liste_Obst.csv', delimiter=';')

score = 0


#Angabe persönliche Daten
print("Willkommen im virtuellen Supermarkt! Du kannst dir Lebensmittel aussuchen und in den Warenkorb legen. \nNach Abschluss des Einkaufs, werden die Lebensmittel innerhalb eines Tages geliefert.")
print("Um eine reibungslose Ausstellung gewährleisten zu können, gebe bitte hier deine Kontaktdaten an:\n")

your_name = input('Dein Name: ')
your_city = input('Deine Stadt: ')
your_country = input('Dein Land: ')



class user():
    user = []
    def __init__(self, your_name, your_city, your_country):
        self.your_name = your_name
        self.your_city = your_city
        self.your_country= your_country
    def __repr__(self):
        return "Name: " + self.your_name + "\nStadt: " + self.your_city + "\nLand: " + self.your_country
user_1 = user(your_name, your_city, your_country)




#Angabe Land
if (your_country == 'Deutschland' or your_country == 'deutschland' or your_country == 'germany' or your_country == 'Germany' or your_country == 'de'):
    print("Vielen Dank,",your_name,"!")
    time.sleep(2)
else:
    print("Oh tut uns Leid, leider können wir keine Lebensmittel ins Ausland liefern! Eine Abholung in Deutschland ist allerdings möglich.")
    time.sleep(2)
print("\nFüge einfach die Lebensmittel hinzu, die du gerne möchtest. Uns liegt Nachhaltigkeit sehr am Herzen.\nWir würden uns deshalb freuen, wenn du bei deinem Einkauf darauf achtest.")


#Angabe Monat
print("Um die Nachhaltigkeit der Lebensmittel besser bewerten zu können, benötigen wir den Monat, in welchem du einkaufst.")

month = input("\nBitte gebe hier den Monat ein: ")
while month not in ['Januar', 'Februar', 'März', 'April', 'Mai', 'Juni', 'Juli', 'August', 'September', 'Oktober', 'November', 'Dezember']:
    print ("Gebe den Monat ausgeschrieben an. Achte auf Groß- und Kleinschreibung. Beispiel: Januar")
    month = input("\nBitte gebe hier den Monat ein: ")


einkaufsliste = []


#Gemüseregal
time.sleep(2)
print(color.GRÜN + color.FETT + "\nHier siehst du unser Gemüsesortiment!\n" + color.END)
print(df[['Lebensmittel', 'Herkunft']])


gemuesenummer=999
while (gemuesenummer >14 or gemuesenummer <0):
    gemuesenummer = input("\nGebe die Zahl des gewünschten Lebensmittels ein: ")
    try:
        gemuesenummer = int(gemuesenummer)
    except:
        print ("Ungültige Eingabe. Dieses Lebensmittel haben wir leider nicht im Sortiment.")
        gemuesenummer = 999

gemuesenummer = int(gemuesenummer)
gemuese = df.iloc[gemuesenummer]
print("\nDu hast erfolgreich 1 ", gemuese[0], "deinem Einkaufskorb hinzugefügt")
einkaufsliste.append(gemuese[0])
score += (df.loc[gemuesenummer][month])        
      


i = "+"
weitergemuese = input("Wenn du ein weiteres Gemüse einkaufen möchtest, tippe auf das + oder, wenn du fertig bist, drücke Enter:")
while weitergemuese == "+":
    gemuesenummer=999
    while (gemuesenummer >14 or gemuesenummer <0):
        gemuesenummer = input("\nGebe die Zahl des gewünschten Lebensmittels ein: ")
        try:
            gemuesenummer = int(gemuesenummer)
        except:
            print ("Ungültige Eingabe. Dieses Lebensmittel haben wir leider nicht im Sortiment.")
            gemuesenummer = 999
    gemuesenummer = int(gemuesenummer)
    gemuese = df.iloc[gemuesenummer]

    print("\nDu hast erfolgreich 1 ", gemuese[0], "dem Warenkorb hinzugefügt")
    einkaufsliste.append(gemuese[0])
    weitergemuese = input("Wenn du ein weiteres Gemüse einkaufen möchtest, tippe auf das + oder, wenn du fertig bist, drücke Enter:")

    score += (df.loc[gemuesenummer][month]) 
    
#Nachhaltigkeitsscore
print("\nIm Moment hast du von 12 möglichen Nachhaltigkeitspunkten", score/len(einkaufsliste),"erreicht.")
print("Deine Einkaufsliste beinhaltet bis jetzt folgende Lebensmittel:\t", einkaufsliste)


#Obstregal
time.sleep(2)
print(color.GRÜN + color.FETT + "\nHier siehst du unser Obstsortiment!\n" + color.END)
print("Welche Lebenmittel möchtest du hier einkaufen?\n") 
print(gv [['Lebensmittel', 'Herkunft']])


obstnummer=999
while (obstnummer >14 or obstnummer <0):
    obstnummer = input("\nGebe die Zahl des gewünschten Lebensmittels ein: ")
    try:
        obstnummer = int(obstnummer)
    except:
        print ("Ungültige Eingabe. Dieses Lebensmittel haben wir leider nicht im Sortiment.")
        obstnummer = 999

obstnummer = int(obstnummer)
obst = gv.iloc[obstnummer]
score += (gv.loc[obstnummer][month])


print("\nDu hast erfolgreich 1 ", obst[0], "dem Warenkorb hinzugefügt")
einkaufsliste.append(obst[0])




i = "+"
weiterobst = input("Wenn du ein weiteres Obst einkaufen möchtest, tippe auf das + oder, wenn du fertig bist, drücke Enter:")
while weiterobst == "+":
    
    obstnummer=999
    while (obstnummer >14 or obstnummer <0):
        obstnummer = input("\nGebe die Zahl des gewünschten Lebensmittels ein: ")
        try:
            obstnummer = int(obstnummer)
        except:
            print ("Ungültige Eingabe. Dieses Lebensmittel haben wir leider nicht im Sortiment.")
            obstnummer = 999

    obstnummer = int(obstnummer)
    obst = gv.iloc[obstnummer]

    print("\nDu hast erfolgreich 1 ", obst[0], "dem Warenkorb hinzugefügt")
    einkaufsliste.append(obst[0])
    weiterobst = input("Wenn du ein weiteres Obst einkaufen möchtest, tippe auf das + oder, wenn du fertig bist, drücke Enter:")

    score += (gv.loc[obstnummer][month])

# Überprüfung der persönlichen Daten
print ("\nFolgende Angaben werden für die Lieferung verwendet: ")
print(user_1)

#Überprüfung des Warenkorbs
time.sleep(1)
print ("\nHier siehst du nochmal deine ausgewählten Lebensmittel: ", einkaufsliste)
time.sleep(1)

#Bewertung des Warenkorbs nach Nachhaltigkeit
if score/len(einkaufsliste) > 8:
    print (color.GRÜN + "\nDu hast von 12 Nachhaltigkeitspunkten", score/len(einkaufsliste), "erreicht.\nSuper! Dein Einkauf war sehr nachhaltig. Weiter so." + color.END)
elif score/len(einkaufsliste) < 4:
    print (color.ROT + "\nDu hast von 12 Nachhaltigkeitspunkten", score/len(einkaufsliste), "erreicht.\nNächstes Mal kannst du versuchen besser auf deine Umwelt zu achten und die Nachhaltigkeit besser im Auge zu behalten." + color.END)
else:
    print (color.GELB + "\nDu hast von 12 Nachhaltigkeitspunkten", score/len(einkaufsliste), "erreicht.\nToll, dass du bereits auf die Nachhaltigkeit geachtet hast. Aber geht das noch besser?" + color.END)

#Bestätigung des Einkaufs
time.sleep(1)
print ("\nWenn du mit deinem Einkauf zufrieden bist, drücke bitte auf bestätigen.")

from IPython.display import display
button = widgets.Button(description="Bestellung bestätigen")
output = widgets.Output()

display(button, output)

def on_button_clicked(b):
    with output:
        print("\nDeine Bestellung wurde bestätigt und die Lebensmittel sind bereits auf dem Weg zu dir.\nVielen Dank und bis zum nächsten Mal!")

button.on_click(on_button_clicked)
# Out:
# Willkommen im virtuellen Supermarkt! Du kannst dir Lebensmittel aussuchen und in den Warenkorb legen.
# Nach Abschluss des Einkaufs, werden die Lebensmittel innerhalb eines Tages geliefert.
# Um eine reibungslose Ausstellung gewährleisten zu können, gebe bitte hier deine Kontaktdaten an:
#
# Dein Name: Isabell
# Deine Stadt: Bittelbronn
# Dein Land: de
# Vielen Dank, Isabell !
#
# Füge einfach die Lebensmittel hinzu, die du gerne möchtest. Uns liegt Nachhaltigkeit sehr am Herzen.
# Wir würden uns deshalb freuen, wenn du bei deinem Einkauf darauf achtest.
# Um die Nachhaltigkeit der Lebensmittel besser bewerten zu können, benötigen wir den Monat, in welchem du einkaufst.
#
# Bitte gebe hier den Monat ein: jdfaöl
# Gebe den Monat ausgeschrieben an. Achte auf Groß- und Kleinschreibung. Beispiel: Januar
#
# Bitte gebe hier den Monat ein: 5786++
# Gebe den Monat ausgeschrieben an. Achte auf Groß- und Kleinschreibung. Beispiel: Januar
#
# Bitte gebe hier den Monat ein: Dezember
#
# Hier siehst du unser Gemüsesortiment!
#
#    Lebensmittel     Herkunft
# 0   Artischocke   Frankreich
# 1     Aubergine      Spanien
# 2       Avocado        Chile
# 3      Brokkoli      Italien
# 4   Champignons  Deutschland
# 5     Chinakohl        Polen
# 6         Gurke      Spanien
# 7       Karotte      Holland
# 8     Kartoffel  Deutschland
# 9        Kürbis  Deutschland
# 10         Mais   Österreich
# 11      Paprika  Niederlande
# 12      Spargel   Österreich
# 13       Tomate  Deutschland
# 14      Zuchini      Italien
#
# Gebe die Zahl des gewünschten Lebensmittels ein: 5
#
# Du hast erfolgreich 1  Chinakohl deinem Einkaufskorb hinzugefügt
# Wenn du ein weiteres Gemüse einkaufen möchtest, tippe auf das + oder, wenn du fertig bist, drücke Enter:+
#
# Gebe die Zahl des gewünschten Lebensmittels ein: 20
#
# Gebe die Zahl des gewünschten Lebensmittels ein: dfsa
# Ungültige Eingabe. Dieses Lebensmittel haben wir leider nicht im Sortiment.
#
# Gebe die Zahl des gewünschten Lebensmittels ein: 5
#
# Du hast erfolgreich 1  Chinakohl dem Warenkorb hinzugefügt
# Wenn du ein weiteres Gemüse einkaufen möchtest, tippe auf das + oder, wenn du fertig bist, drücke Enter:
#
# Im Moment hast du von 12 möglichen Nachhaltigkeitspunkten 8.0 erreicht.
# Deine Einkaufsliste beinhaltet bis jetzt folgende Lebensmittel:	 ['Chinakohl', 'Chinakohl']
#
# Hier siehst du unser Obstsortiment!
#
# Welche Lebenmittel möchtest du hier einkaufen?
#
#     Lebensmittel     Herkunft
# 0         Ananas        China
# 1          Apfel  Deutschland
# 2       Aprikose       Türkei
# 3          Birne  Deutschland
# 4       Erdbeere  Deutschland
# 5     Grapefruit  Argentinien
# 6    Heidelbeere      Spanien
# 7       Himbeere    Nordasien
# 8          Mango       Mexico
# 9       Aprikose      Italien
# 10       Pflaume  Deutschland
# 11        Pomelo    Südafrika
# 12       Walnuss  Deutschland
# 13  Wassermelone    Südafrika
# 14       Trauben   Frankreich
#
# Gebe die Zahl des gewünschten Lebensmittels ein: 4
#
# Du hast erfolgreich 1  Erdbeere dem Warenkorb hinzugefügt
# Wenn du ein weiteres Obst einkaufen möchtest, tippe auf das + oder, wenn du fertig bist, drücke Enter:+
#
# Gebe die Zahl des gewünschten Lebensmittels ein: 2
#
# Du hast erfolgreich 1  Aprikose dem Warenkorb hinzugefügt
# Wenn du ein weiteres Obst einkaufen möchtest, tippe auf das + oder, wenn du fertig bist, drücke Enter:+
#
# Gebe die Zahl des gewünschten Lebensmittels ein: 1
#
# Du hast erfolgreich 1  Apfel dem Warenkorb hinzugefügt
# Wenn du ein weiteres Obst einkaufen möchtest, tippe auf das + oder, wenn du fertig bist, drücke Enter:+
#
# Gebe die Zahl des gewünschten Lebensmittels ein: 0
#
# Du hast erfolgreich 1  Ananas dem Warenkorb hinzugefügt
# Wenn du ein weiteres Obst einkaufen möchtest, tippe auf das + oder, wenn du fertig bist, drücke Enter:
#
# Folgende Angaben werden für die Lieferung verwendet:
# Name: Isabell
# Stadt: Bittelbronn
# Land: de
#
# Hier siehst du nochmal deine ausgewählten Lebensmittel:  ['Chinakohl', 'Chinakohl', 'Erdbeere', 'Aprikose', 'Apfel', 'Ananas']
#
# Du hast von 12 Nachhaltigkeitspunkten 5.833333333333333 erreicht.
# Toll, dass du bereits auf die Nachhaltigkeit geachtet hast. Aber geht das noch besser?
#
# Wenn du mit deinem Einkauf zufrieden bist, drücke bitte auf bestätigen.
# Button(description='Bestellung bestätigen', style=ButtonStyle())
# Output()
