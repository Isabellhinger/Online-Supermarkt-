# %%
# Anna Dreier, Norina Eisenbacher, Isabell Hinger (262330)
# Online Supermarkt 

punkte = 0

print("Willkommen im virtuellen Supermarkt! Du kannst dir Lebensmittel aussuchen und in den Warenkorb legen. Nach Abschluss des Einkaufs, werden die Lebensmittel innerhalb eines Tages geliefert")
print("Um eine reibungslose Ausstellung gewährleisten zu können, gebe bitte hier deine Kontaktdaten an:")

your_name=input('Dein Name: ')
your_city=input('Deine Stadt: ')
your_country=input('Dein Land: ')

print("Vielen Dank,", your_name , "!")
print("\nFüge einfach die Lebensmittel hinzu, die du gerne möchtest. Am Ende wird dein Einkauf nach Nachhaltigkeit bewertet\n")

#bitte gebe an, welchen Monat wir gerade haben
#if Januar dann schaue in 2 Spalte nach
#...

import csv
from operator import itemgetter, attrgetter

with open('Liste_Gemüse.csv', 'r', encoding='latin1') as csvfile:
    values = csv.reader(csvfile, delimiter=';', quotechar='"')
    next(values)
    listValues = list(values) 
    listValues = sorted(listValues, key=itemgetter(1))
# Gemüseregal
    for row in listValues:
        print (row[0], row[1], "\tHerkunft: ", row[2]) 
        
        
class Lebensmittel:
  def __init__(self, Obst, Herkunft, Januar, Februar, März, April, Mai, Juni, Juli, August, September, Oktober, November, Dezember):
    self.Obst = Obst
    self.Herkunft = Herkunft
    self.Januar = Januar 
    self.Februar = Februar
    self.März = März 
    self.April = April
    self.Mai = Mai 
    self.Juni = Februar
    
#einfügen welche Lebensmittel ausgewählt werden
#Punkte berechnen
        
# Obstregal (Datei muss noch geimportet werden)



#nochmal sagen, welche Produkte gewählt wurden und wie nachhaltig der Einkauf war
#Vielen Dank!...
# Out:
# Willkommen im virtuellen Supermarkt! Du kannst dir Lebensmittel aussuchen und in den Warenkorb legen. Nach Abschluss des Einkaufs, werden die Lebensmittel innerhalb eines Tages geliefert
# Um eine reibungslose Ausstellung gewährleisten zu können, gebe bitte hier deine Kontaktdaten an:
# Dein Name:
# Deine Stadt:
# Dein Land:
# Vielen Dank,  !
#
# Füge einfach die Lebensmittel hinzu, die du gerne möchtest. Am Ende wird dein Einkauf nach Nachhaltigkeit bewertet
#
# 1 Artischocke  	Herkunft:  Nordafrika
# 2 Aubergine    	Herkunft:  Asien
# 3 Avocado      	Herkunft:  Suedamerika
# 4 Brokkoli     	Herkunft:  Kleinasien
# 5 Champignons  	Herkunft:  Europa
# 6 Chinakohl    	Herkunft:  Polen
# 7 Gurke        	Herkunft:  Spanien
# 8 Karotte      	Herkunft:  Holland
# 9 Kartoffel    	Herkunft:  Deutschland
# 10 Kuerbis      	Herkunft:  Deutschland
# 11 Mais         	Herkunft:  Chile
# 12 Paprika      	Herkunft:  Niederlande
# 13 Spargel      	Herkunft:  Oesterreich
# ...
